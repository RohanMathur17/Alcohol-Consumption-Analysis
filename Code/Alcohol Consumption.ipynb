# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_por = pd.read_csv('E:\Rohan\Datasets\Alcohol Consumption\student-por.csv')
df_mat = pd.read_csv('E:\Rohan\Datasets\Alcohol Consumption\student-mat.csv')

# %%
df_por.shape
# Out:
# (649, 33)

# %%
df_por.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
df_por.shape
# Out:
# (649, 33)

# %%
df_por.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
#  19  nursery     649 non-null    object
#  20  higher      649 non-null    object
#  21  internet    649 non-null    object
#  22  romantic    649 non-null    object
#  23  famrel      649 non-null    int64
#  24  freetime    649 non-null    int64
#  25  goout       649 non-null    int64
#  26  Dalc        649 non-null    int64
#  27  Walc        649 non-null    int64
#  28  health      649 non-null    int64
#  29  absences    649 non-null    int64
#  30  G1          649 non-null    int64
#  31  G2          649 non-null    int64
#  32  G3          649 non-null    int64
# dtypes: int64(16), object(17)
# memory usage: 167.4+ KB

# %%
column= ['School','Sex','Age','Address','Family_Size','Parent_Status','Mother_Edu','Father_Edu','Mjob','Fjob',
          'Reason','Guardian','Travel_Time','Study_Time','Failures','School_Support','Family_Support','Paid',
          'Extra_C_Activity','Nursery','Higher','Internet','Romantic','Family_Relationship','Freetime','Outings',
         'Alcohol_Wday','Alcohol_Wend','Health','Absent','G1','G2',"G3"]
df_por.columns= column

# %%
df_por.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   School               649 non-null    object
#  1   Sex                  649 non-null    object
#  2   Age                  649 non-null    int64
#  3   Address              649 non-null    object
#  4   Family_Size          649 non-null    object
#  5   Parent_Status        649 non-null    object
#  6   Mother_Edu           649 non-null    int64
#  7   Father_Edu           649 non-null    int64
#  8   Mjob                 649 non-null    object
#  9   Fjob                 649 non-null    object
#  10  Reason               649 non-null    object
#  11  Guardian             649 non-null    object
#  12  Travel_Time          649 non-null    int64
#  13  Study_Time           649 non-null    int64
#  14  Failures             649 non-null    int64
#  15  School_Support       649 non-null    object
#  16  Family_Support       649 non-null    object
#  17  Paid                 649 non-null    object
#  18  Extra_C_Activity     649 non-null    object
#  19  Nursery              649 non-null    object
#  20  Higher               649 non-null    object
#  21  Internet             649 non-null    object
#  22  Romantic             649 non-null    object
#  23  Family_Relationship  649 non-null    int64
#  24  Freetime             649 non-null    int64
#  25  Outings              649 non-null    int64
#  26  Alcohol_Wday         649 non-null    int64
#  27  Alcohol_Wend         649 non-null    int64
#  28  Health               649 non-null    int64
#  29  Absent               649 non-null    int64
#  30  G1                   649 non-null    int64
#  31  G2                   649 non-null    int64
#  32  G3                   649 non-null    int64
# dtypes: int64(16), object(17)
# memory usage: 167.4+ KB

# %%
df_por.isnull().sum().sum()
# Out:
# 0

# %%
duplicates=df_por.duplicated().tolist()
true= [i for i in duplicates if i==True]
true
# Out:
# []

# %%
df_por.describe(include='all')
# Out:
#        School  Sex         Age Address Family_Size Parent_Status  Mother_Edu  \
# count     649  649  649.000000     649         649           649  649.000000
# unique      2    2         NaN       2           2             2         NaN
# top        GP    F         NaN       U         GT3             T         NaN
# freq      423  383         NaN     452         457           569         NaN
# mean      NaN  NaN   16.744222     NaN         NaN           NaN    2.514638
# std       NaN  NaN    1.218138     NaN         NaN           NaN    1.134552
# min       NaN  NaN   15.000000     NaN         NaN           NaN    0.000000
# 25%       NaN  NaN   16.000000     NaN         NaN           NaN    2.000000
# 50%       NaN  NaN   17.000000     NaN         NaN           NaN    2.000000
# 75%       NaN  NaN   18.000000     NaN         NaN           NaN    4.000000
# max       NaN  NaN   22.000000     NaN         NaN           NaN    4.000000
#
#         Father_Edu   Mjob   Fjob  ... Family_Relationship    Freetime  \
# count   649.000000    649    649  ...          649.000000  649.000000
# unique         NaN      5      5  ...                 NaN         NaN
# top            NaN  other  other  ...                 NaN         NaN
# freq           NaN    258    367  ...                 NaN         NaN
# mean      2.306626    NaN    NaN  ...            3.930663    3.180277
# std       1.099931    NaN    NaN  ...            0.955717    1.051093
# min       0.000000    NaN    NaN  ...            1.000000    1.000000
# 25%       1.000000    NaN    NaN  ...            4.000000    3.000000
# 50%       2.000000    NaN    NaN  ...            4.000000    3.000000
# 75%       3.000000    NaN    NaN  ...            5.000000    4.000000
# max       4.000000    NaN    NaN  ...            5.000000    5.000000
#
#            Outings  Alcohol_Wday  Alcohol_Wend      Health      Absent  \
# count   649.000000    649.000000    649.000000  649.000000  649.000000
# unique         NaN           NaN           NaN         NaN         NaN
# top            NaN           NaN           NaN         NaN         NaN
# freq           NaN           NaN           NaN         NaN         NaN
# mean      3.184900      1.502311      2.280431    3.536210    3.659476
# std       1.175766      0.924834      1.284380    1.446259    4.640759
# min       1.000000      1.000000      1.000000    1.000000    0.000000
# 25%       2.000000      1.000000      1.000000    2.000000    0.000000
# 50%       3.000000      1.000000      2.000000    4.000000    2.000000
# 75%       4.000000      2.000000      3.000000    5.000000    6.000000
# max       5.000000      5.000000      5.000000    5.000000   32.000000
#
#                 G1          G2          G3
# count   649.000000  649.000000  649.000000
# unique         NaN         NaN         NaN
# top            NaN         NaN         NaN
# freq           NaN         NaN         NaN
# mean     11.399076   11.570108   11.906009
# std       2.745265    2.913639    3.230656
# min       0.000000    0.000000    0.000000
# 25%      10.000000   10.000000   10.000000
# 50%      11.000000   11.000000   12.000000
# 75%      13.000000   13.000000   14.000000
# max      19.000000   19.000000   19.000000
#
# [11 rows x 33 columns]

# %%
df_por.corr()
# Out:
#                           Age  Mother_Edu  Father_Edu  Travel_Time  \
# Age                  1.000000   -0.107832   -0.121050     0.034490
# Mother_Edu          -0.107832    1.000000    0.647477    -0.265079
# Father_Edu          -0.121050    0.647477    1.000000    -0.208288
# Travel_Time          0.034490   -0.265079   -0.208288     1.000000
# Study_Time          -0.008415    0.097006    0.050400    -0.063154
# Failures             0.319968   -0.172210   -0.165915     0.097730
# Family_Relationship -0.020559    0.024421    0.020256    -0.009521
# Freetime            -0.004910   -0.019686    0.006841     0.000937
# Outings              0.112805    0.009536    0.027690     0.057454
# Alcohol_Wday         0.134768   -0.007018    0.000061     0.092824
# Alcohol_Wend         0.086357   -0.019766    0.038445     0.057007
# Health              -0.008750    0.004614    0.044910    -0.048261
# Absent               0.149998   -0.008577    0.029859    -0.008149
# Alcohol_Wday        -0.195171 -0.189480 -0.204719
# Alcohol_Wend        -0.155649 -0.164852 -0.176619
# Health              -0.051647 -0.082179 -0.098851
# Absent              -0.147149 -0.124745 -0.091379
# G1                   1.000000  0.864982  0.826387
# G2                   0.864982  1.000000  0.918548
# G3                   0.826387  0.918548  1.000000

# %%
df_por['Alcohol'] = df_por['Alcohol_Wday']+df_por['Alcohol_Wend']

# %%
alcohol_mean = df_por.Alcohol.mean()
print(alcohol_mean)
df_alcohol=df_por.query('Alcohol > @alcohol_mean')
# Out:
# 3.782742681047766

# %%
print(df_alcohol['Study_Time'].mean(),df_por['Study_Time'].mean())
# Out:
# 1.7876712328767124 1.9306625577812018

# %%
df_alcohol.shape
# Out:
# (292, 34)

# %%
print(df_alcohol['Study_Time'].max() , df_por['Study_Time'].max())
# Out:
# 4 4

# %%
df_por['Family_Relationship'].value_counts()
# Out:
# 4    317
# 5    180
# 3    101
# 2     29
# 1     22
# Name: Family_Relationship, dtype: int64

# %%
df_alcohol['Family_Relationship'].value_counts()
# Out:
# 4    142
# 5     68
# 3     53
# 2     18
# 1     11
# Name: Family_Relationship, dtype: int64

# %%
fig, axs = plt.subplots(1,2 , figsize=(15, 5))
sns.countplot( df_por['Family_Relationship'] ,ax = axs[0] )
sns.countplot( df_alcohol['Family_Relationship'] ,ax=axs[1])

# %%
value_counts_fam_relationship=df_por['Family_Relationship'].value_counts().tolist() 
unique_fam_relationship=df_por['Family_Relationship'].unique().tolist() 

perc_fam_relationship = [i/len(df_por) for i in value_counts_fam_relationship ]
perc_fam_relationship
dict_fam_relationship = dict(zip(unique_fam_relationship,perc_fam_relationship))
print(dict_fam_relationship)




value_counts_fam_relationship=df_alcohol['Family_Relationship'].value_counts().tolist() 
unique_fam_relationship=df_alcohol['Family_Relationship'].unique().tolist() 

perc_fam_relationship_alcohol = [i/len(df_por) for i in value_counts_fam_relationship ]
perc_fam_relationship_alcohol
dict_fam_relationship_alcohol = dict(zip(unique_fam_relationship,perc_fam_relationship_alcohol))
print(dict_fam_relationship_alcohol)
# Out:
# {4: 0.4884437596302003, 5: 0.2773497688751926, 3: 0.15562403697996918, 1: 0.04468412942989214, 2: 0.03389830508474576}
# {4: 0.21879815100154082, 5: 0.10477657935285054, 3: 0.08166409861325115, 1: 0.02773497688751926, 2: 0.01694915254237288}

# %%
fig, axs = plt.subplots(1,2 , figsize=(15, 5))
sns.barplot(x=unique_fam_relationship,y = perc_fam_relationship,ax = axs[0] )
sns.barplot( x=unique_fam_relationship ,y=perc_fam_relationship_alcohol,ax=axs[1])

# %%
sns.distplot(df_por['Alcohol_Wday'] , kde=False, color='red' )

# %%
sns.distplot(df_por['Alcohol_Wend'] , kde=False, color='red' )
